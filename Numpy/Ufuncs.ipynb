# %%
import numpy as np
"""
Ufuncs are used to implement vectorization in NumPy which is way faster than iterating over elements.
Ufuncs also take additional arguments, like:
    'where' boolean array or condition defining where the operations should take place.
    'dtype' defining the return type of elements.
    'out' output array where the return value should be copied.
Converting iterative statements (loops) into a vector based operation is called vectorization.
"""

#Consider a scenario where we need to calculate the reciprocal of array for which the traditional approach is to loop through the array etc:

rng = np.random.default_rng(seed=1701)

def compute_reciprocal(array):
    output = np.empty(len(array))
    for i in range(len(array)):
        output[i] = 1/array[i]
    return output


array = rng.integers(1,100, size = 1000000)
# %timeit compute_reciprocal(array)
# Out:
# 165 ms ± 2.38 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
#now using vectorized operation for the same task:
# %timeit 1/array
# Out:
# 2.45 ms ± 85.6 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
#vectorized operations are a wrapper of ufuncs.. like ufunc for / is np.divide(), + is np.add(), np.mod(), np.power() etc
